# %% [markdown]
# # 이미지 생성 Fune-tuning project

# %% [markdown]
# ## 동양풍의 이미지를 생성하기 위해 프롬프트에 맞는 이미지 생성 AI Fine-tuning

# %%
from diffusers import DiffusionPipeline

# model_id = "CompVis/stable-diffusion-v1-4"
# pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
# pipe.to("cpu")

# prompt = "a beautiful landscape with mountains and rivers"
# image = pipe(prompt).images[0]
# image.save("output.png")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:920, in _LazyModule._get_module(self, module_name)
#     919 try:
# --> 920     return importlib.import_module("." + module_name, self.__name__)
#     921 except Exception as e:
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/loaders/peft.py:40
#      25 from ..utils import (
#      26     MIN_PEFT_VERSION,
#      27     USE_PEFT_BACKEND,
#    (...)
#      38     set_weights_and_activate_adapters,
#      39 )
# ---> 40 from .lora_base import _fetch_state_dict
#      41 from .unet_loader_utils import _maybe_expand_lora_scales
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/loaders/lora_base.py:47
#      46 if is_peft_available():
# ---> 47     from peft.tuners.tuners_utils import BaseTunerLayer
#      49 if is_accelerate_available():
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/peft/tuners/tuners_utils.py:34
#      32 from transformers.pytorch_utils import Conv1D
# ---> 34 from peft.utils import INCLUDE_LINEAR_LAYERS_SHORTHAND
#      35 from peft.utils.constants import (
#      36     DUMMY_MODEL_CONFIG,
#      37     DUMMY_TARGET_MODULES,
#    (...)
#      40     SEQ_CLS_HEAD_NAMES,
#      41 )
#
# ImportError: cannot import name 'INCLUDE_LINEAR_LAYERS_SHORTHAND' from 'peft.utils' (/opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/peft/utils/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:920, in _LazyModule._get_module(self, module_name)
#     919 try:
# --> 920     return importlib.import_module("." + module_name, self.__name__)
#     921 except Exception as e:
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/autoencoders/__init__.py:1
# ----> 1 from .autoencoder_asym_kl import AsymmetricAutoencoderKL
#       2 from .autoencoder_dc import AutoencoderDC
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/autoencoders/autoencoder_asym_kl.py:23
#      22 from ..modeling_utils import ModelMixin
# ---> 23 from .vae import DecoderOutput, DiagonalGaussianDistribution, Encoder, MaskConditionDecoder
#      26 class AsymmetricAutoencoderKL(ModelMixin, ConfigMixin):
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/autoencoders/vae.py:25
#      24 from ..attention_processor import SpatialNorm
# ---> 25 from ..unets.unet_2d_blocks import (
#      26     AutoencoderTinyBlock,
#      27     UNetMidBlock2D,
#      28     get_down_block,
#      29     get_up_block,
#      30 )
#      33 @dataclass
#      34 class EncoderOutput(BaseOutput):
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/unets/__init__.py:6
#       5 from .unet_1d import UNet1DModel
# ----> 6 from .unet_2d import UNet2DModel
#       7 from .unet_2d_condition import UNet2DConditionModel
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/unets/unet_2d.py:24
#      23 from ..modeling_utils import ModelMixin
# ---> 24 from .unet_2d_blocks import UNetMidBlock2D, get_down_block, get_up_block
#      27 @dataclass
#      28 class UNet2DOutput(BaseOutput):
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/unets/unet_2d_blocks.py:36
#      26 from ..resnet import (
#      27     Downsample2D,
#      28     FirDownsample2D,
#    (...)
#      34     Upsample2D,
#      35 )
# ---> 36 from ..transformers.dual_transformer_2d import DualTransformer2DModel
#      37 from ..transformers.transformer_2d import Transformer2DModel
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/transformers/__init__.py:6
#       5 from .auraflow_transformer_2d import AuraFlowTransformer2DModel
# ----> 6 from .cogvideox_transformer_3d import CogVideoXTransformer3DModel
#       7 from .dit_transformer_2d import DiTTransformer2DModel
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/transformers/cogvideox_transformer_3d.py:22
#      21 from ...configuration_utils import ConfigMixin, register_to_config
# ---> 22 from ...loaders import PeftAdapterMixin
#      23 from ...utils import USE_PEFT_BACKEND, is_torch_version, logging, scale_lora_layers, unscale_lora_layers
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:910, in _LazyModule.__getattr__(self, name)
#     909 elif name in self._class_to_module.keys():
# --> 910     module = self._get_module(self._class_to_module[name])
#     911     value = getattr(module, name)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:922, in _LazyModule._get_module(self, module_name)
#     921 except Exception as e:
# --> 922     raise RuntimeError(
#     923         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     924         f" traceback):\n{e}"
#     925     ) from e
#
# RuntimeError: Failed to import diffusers.loaders.peft because of the following error (look up to see its traceback):
# cannot import name 'INCLUDE_LINEAR_LAYERS_SHORTHAND' from 'peft.utils' (/opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/peft/utils/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:920, in _LazyModule._get_module(self, module_name)
#     919 try:
# --> 920     return importlib.import_module("." + module_name, self.__name__)
#     921 except Exception as e:
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/pipelines/pipeline_utils.py:45
#      44 from ..configuration_utils import ConfigMixin
# ---> 45 from ..models import AutoencoderKL
#      46 from ..models.attention_processor import FusedAttnProcessor2_0
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:910, in _LazyModule.__getattr__(self, name)
#     909 elif name in self._class_to_module.keys():
# --> 910     module = self._get_module(self._class_to_module[name])
#     911     value = getattr(module, name)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:922, in _LazyModule._get_module(self, module_name)
#     921 except Exception as e:
# --> 922     raise RuntimeError(
#     923         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     924         f" traceback):\n{e}"
#     925     ) from e
#
# RuntimeError: Failed to import diffusers.models.autoencoders.autoencoder_kl because of the following error (look up to see its traceback):
# Failed to import diffusers.loaders.peft because of the following error (look up to see its traceback):
# cannot import name 'INCLUDE_LINEAR_LAYERS_SHORTHAND' from 'peft.utils' (/opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/peft/utils/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 from diffusers import DiffusionPipeline
#       3 # model_id = "CompVis/stable-diffusion-v1-4"
#       4 # pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
#       5 # pipe.to("cpu")
#    (...)
#       8 # image = pipe(prompt).images[0]
#       9 # image.save("output.png")
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:911, in _LazyModule.__getattr__(self, name)
#     909 elif name in self._class_to_module.keys():
#     910     module = self._get_module(self._class_to_module[name])
# --> 911     value = getattr(module, name)
#     912 else:
#     913     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:910, in _LazyModule.__getattr__(self, name)
#     908     value = self._get_module(name)
#     909 elif name in self._class_to_module.keys():
# --> 910     module = self._get_module(self._class_to_module[name])
#     911     value = getattr(module, name)
#     912 else:
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:922, in _LazyModule._get_module(self, module_name)
#     920     return importlib.import_module("." + module_name, self.__name__)
#     921 except Exception as e:
# --> 922     raise RuntimeError(
#     923         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     924         f" traceback):\n{e}"
#     925     ) from e
#
# RuntimeError: Failed to import diffusers.pipelines.pipeline_utils because of the following error (look up to see its traceback):
# Failed to import diffusers.models.autoencoders.autoencoder_kl because of the following error (look up to see its traceback):
# Failed to import diffusers.loaders.peft because of the following error (look up to see its traceback):
# cannot import name 'INCLUDE_LINEAR_LAYERS_SHORTHAND' from 'peft.utils' (/opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/peft/utils/__init__.py)

# %%
# !pip install --upgrade peft
# !pip install --upgrade accelerate
# !pip install --upgrade diffusers
from diffusers import DiffusionPipeline
# Out:
# /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:920, in _LazyModule._get_module(self, module_name)
#     919 try:
# --> 920     return importlib.import_module("." + module_name, self.__name__)
#     921 except Exception as e:
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/autoencoders/__init__.py:1
# ----> 1 from .autoencoder_asym_kl import AsymmetricAutoencoderKL
#       2 from .autoencoder_dc import AutoencoderDC
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/autoencoders/autoencoder_asym_kl.py:22
#      21 from ..modeling_outputs import AutoencoderKLOutput
# ---> 22 from ..modeling_utils import ModelMixin
#      23 from .vae import DecoderOutput, DiagonalGaussianDistribution, Encoder, MaskConditionDecoder
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/models/modeling_utils.py:35
#      34 from .. import __version__
# ---> 35 from ..quantizers import DiffusersAutoQuantizer, DiffusersQuantizer
#      36 from ..quantizers.quantization_config import QuantizationMethod
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/quantizers/__init__.py:15
#       1 # Copyright 2024 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from .auto import DiffusersAutoQuantizer
#      16 from .base import DiffusersQuantizer
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/quantizers/auto.py:22
#      20 from typing import Dict, Optional, Union
# ---> 22 from .bitsandbytes import BnB4BitDiffusersQuantizer, BnB8BitDiffusersQuantizer
#      23 from .gguf import GGUFQuantizer
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/quantizers/bitsandbytes/__init__.py:2
#       1 from .bnb_quantizer import BnB4BitDiffusersQuantizer, BnB8BitDiffusersQuantizer
# ----> 2 from .utils import dequantize_and_replace, dequantize_bnb_weight, replace_with_bnb_linear
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/quantizers/bitsandbytes/utils.py:32
#      31 if is_bitsandbytes_available():
# ---> 32     import bitsandbytes as bnb
#      34 if is_accelerate_available():
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/bitsandbytes/__init__.py:6
#       1 # Copyright (c) Facebook, Inc. and its affiliates.
#       2 #
#       3 # This source code is licensed under the MIT license found in the
#       4 # LICENSE file in the root directory of this source tree.
# ----> 6 from . import cuda_setup, utils, research
#       7 from .autograd._functions import (
#       8     MatmulLtState,
#       9     bmm_cublas,
#    (...)
#      13     matmul_4bit
#      14 )
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/bitsandbytes/research/__init__.py:1
# ----> 1 from . import nn
#       2 from .autograd._functions import (
#       3     switchback_bnb,
#       4     matmul_fp8_global,
#       5     matmul_fp8_mixed,
#       6 )
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/bitsandbytes/research/nn/__init__.py:1
# ----> 1 from .modules import LinearFP8Mixed, LinearFP8Global
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/bitsandbytes/research/nn/modules.py:8
#       7 import bitsandbytes as bnb
# ----> 8 from bitsandbytes.optim import GlobalOptimManager
#       9 from bitsandbytes.utils import OutlierTracer, find_outlier_dims
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/bitsandbytes/optim/__init__.py:8
#       6 from bitsandbytes.cextension import COMPILED_WITH_CUDA
# ----> 8 from .adagrad import Adagrad, Adagrad8bit, Adagrad32bit
#       9 from .adam import Adam, Adam8bit, Adam32bit, PagedAdam, PagedAdam8bit, PagedAdam32bit
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/bitsandbytes/optim/adagrad.py:5
#       1 # Copyright (c) Facebook, Inc. and its affiliates.
#       2 #
#       3 # This source code is licensed under the MIT license found in the
#       4 # LICENSE file in the root directory of this source tree.
# ----> 5 from bitsandbytes.optim.optimizer import Optimizer1State
#       8 class Adagrad(Optimizer1State):
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/bitsandbytes/optim/optimizer.py:12
#      10 import torch
# ---> 12 import bitsandbytes.functional as F
#      15 class MockArgs:
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/bitsandbytes/functional.py:12
#      11 import math
# ---> 12 from scipy.stats import norm
#      13 import numpy as np
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/scipy/stats/__init__.py:606
#     604 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     605                                DegenerateDataWarning, FitError)
# --> 606 from ._stats_py import *
#     607 from ._variation import variation
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/scipy/stats/_stats_py.py:49
#      48 from scipy import linalg
# ---> 49 from . import distributions
#      50 from . import _mstats_basic as mstats_basic
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/scipy/stats/distributions.py:11
#      10 from . import _continuous_distns
# ---> 11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/scipy/stats/_discrete_distns.py:10
#       9 from scipy._lib._util import _lazywhere, rng_integers
# ---> 10 from scipy.interpolate import interp1d
#      12 from numpy import floor, ceil, log, exp, sqrt, log1p, expm1, tanh, cosh, sinh
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/scipy/interpolate/__init__.py:167
#       1 """
#       2 ========================================
#       3 Interpolation (:mod:`scipy.interpolate`)
#    (...)
#     165 (should not be used in new code).
#     166 """
# --> 167 from ._interpolate import *
#     168 from ._fitpack_py import *
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/scipy/interpolate/_interpolate.py:14
#      12 from scipy.special import comb
# ---> 14 from . import _fitpack_py
#      15 from . import dfitpack
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/scipy/interpolate/_fitpack_py.py:8
#       7 # These are in the API for fitpack even if not used in fitpack.py itself.
# ----> 8 from ._fitpack_impl import bisplrep, bisplev, dblint  # noqa: F401
#       9 from . import _fitpack_impl as _impl
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/scipy/interpolate/_fitpack_impl.py:103
#      71 _iermess2 = {
#      72     0: ["The spline has a residual sum of squares fp such that "
#      73         "abs(fp-s)/s<=0.001", None],
#    (...)
#      99     'unknown': ["An error occurred", TypeError]
#     100 }
#     102 _parcur_cache = {'t': array([], float), 'wrk': array([], float),
# --> 103                  'iwrk': array([], dfitpack_int), 'u': array([], float),
#     104                  'ub': 0, 'ue': 1}
#     107 def splprep(x, w=None, u=None, ub=None, ue=None, k=3, task=0, s=None, t=None,
#     108             full_output=0, nest=None, per=0, quiet=1):
#     109     # see the docstring of `_fitpack_py/splprep`
#
# TypeError:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:920, in _LazyModule._get_module(self, module_name)
#     919 try:
# --> 920     return importlib.import_module("." + module_name, self.__name__)
#     921 except Exception as e:
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/pipelines/pipeline_utils.py:45
#      44 from ..configuration_utils import ConfigMixin
# ---> 45 from ..models import AutoencoderKL
#      46 from ..models.attention_processor import FusedAttnProcessor2_0
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:910, in _LazyModule.__getattr__(self, name)
#     909 elif name in self._class_to_module.keys():
# --> 910     module = self._get_module(self._class_to_module[name])
#     911     value = getattr(module, name)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:922, in _LazyModule._get_module(self, module_name)
#     921 except Exception as e:
# --> 922     raise RuntimeError(
#     923         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     924         f" traceback):\n{e}"
#     925     ) from e
#
# RuntimeError: Failed to import diffusers.models.autoencoders.autoencoder_kl because of the following error (look up to see its traceback):
#
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 4
#       1 # !pip install --upgrade peft
#       2 # !pip install --upgrade accelerate
#       3 # !pip install --upgrade diffusers
# ----> 4 from diffusers import DiffusionPipeline
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:911, in _LazyModule.__getattr__(self, name)
#     909 elif name in self._class_to_module.keys():
#     910     module = self._get_module(self._class_to_module[name])
# --> 911     value = getattr(module, name)
#     912 else:
#     913     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:910, in _LazyModule.__getattr__(self, name)
#     908     value = self._get_module(name)
#     909 elif name in self._class_to_module.keys():
# --> 910     module = self._get_module(self._class_to_module[name])
#     911     value = getattr(module, name)
#     912 else:
#
# File /opt/homebrew/anaconda3/envs/llm/lib/python3.9/site-packages/diffusers/utils/import_utils.py:922, in _LazyModule._get_module(self, module_name)
#     920     return importlib.import_module("." + module_name, self.__name__)
#     921 except Exception as e:
# --> 922     raise RuntimeError(
#     923         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     924         f" traceback):\n{e}"
#     925     ) from e
#
# RuntimeError: Failed to import diffusers.pipelines.pipeline_utils because of the following error (look up to see its traceback):
# Failed to import diffusers.models.autoencoders.autoencoder_kl because of the following error (look up to see its traceback):
